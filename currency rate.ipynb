# %%
import cnb_exchange_rate
import datetime

# %%
cnb_exchange_rate.daily_rate('EUR', datetime.date(2025, 1, 2))
# Out:
# 3.924

# %%
cnb_exchange_rate.monthly_rate('EUR', 2025, 1)
# Out:
# 25.162

# %%
date = datetime.date(2025, 1, 2)
currencies = ['EUR', 'USD', 'CHF', 'BRL']
rates = [f"{curr}: {cnb_exchange_rate.daily_rate(curr, date):.3f}" for curr in currencies]
print("\n".join(rates))
# Out:
# EUR: 25.175
# USD: 24.398
# CHF: 26.863
# BRL: 3.924
